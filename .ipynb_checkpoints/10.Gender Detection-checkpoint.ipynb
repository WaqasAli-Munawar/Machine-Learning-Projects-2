# %% [markdown]
# Gender Detection is based on the applications of computer vision. There are so many **computer vision** libraries in Python that we can use for recognizing the gender of a human being. In this article, we will use **OpenCV and cvlib libraries** for Gender Detection with machine learning using Python.

# %% [markdown]
# We can use machine learning to detect the gender of a human using the facial appearance samples of men and women.
# * Facial appearance is one of the common ways that we humans use to recognize the gender of another person. We can also use a person’s voice, but the best approach is to train a model with high-level characteristics of human beings such as:
#
#     * distance between eyes, nose and mouth
#     * measurements of different parts of the faces of both genders.
#
# This is how a machine learning model can be trained for recognizing the gender of a human being. But since Python provides libraries for almost every possible task today, we can also use the **OpenCV and cvlib libraries** in Python to detect a person’s gender.

# %%
# !pip install opencv-python
# !pip install cvlib
# Out:
# ...
#      |████████████████████████████████| 10.0 MB 8.4 MB/s
# ...
#   Created wheel for cvlib: filename=cvlib-0.2.6-py3-none-any.whl size=10044619 sha256=3311027cc95a51f13ee912ea535c13d5e01b138a62d8b5e19a272d543453a134
#   Stored in directory: /root/.cache/pip/wheels/9b/96/9b/373c07517ffe0bedbebc0813aec1e62cb2bb1dee91b3694895
# ...
#   Created wheel for progressbar: filename=progressbar-2.5-py3-none-any.whl size=12082 sha256=6db7736e443e701a66db7296f20f01c8ee79781c4f15e924f7965878ee1716b1
#   Stored in directory: /root/.cache/pip/wheels/f0/fd/1f/3e35ed57e94cd8ced38dd46771f1f0f94f65fec548659ed855
# Successfully built cvlib progressbar
# ...

# %%
import cv2
import cvlib as cv
import sys
import numpy as np
from numpy.lib.type_check import imag

# %%
image = cv2.imread("waqas.JPG")

# %%
image.shape
# Out:
# (768, 1024, 3)

# %% [markdown]
# Now below is how we can use the **OpenCV and cvlib libraries** for Gender Detection:

# %%
face, confidence = cv.detect_face(image)
padding = 20

for i in face:
    (x, y) = max(0, i[0]-padding), max(0, i[1]-padding)
    (x2, y2) = min(image.shape[1]-1, i[2]+padding), min(image.shape[0]-1,i[3]+padding)
    cv2.rectangle(image, (x, y), (x2, y2), (0, 255, 0), 2)
    crop = np.copy(image[y:y2, x:x2])
    (label, confidence) = cv.detect_gender(crop)
    idx = np.argmax(confidence)
    label = label[idx]
    label = "{}: {:.2f}%".format(label, confidence[idx] * 100)
    Y = y - 10 if y -10 > 10 else y + 10
    cv2.putText(image, label, (y, Y), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
# Out:
# ...
# 45662208/45649168 [==============================] - 1s 0us/step
# [INFO] Initializing gender detection model ..

# %%
from google.colab.patches import cv2_imshow
# cv2.imshow("Gender Detection", image)
cv2_imshow(image)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F7280068DD0>
